# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("bank-additional-full.csv", delimiter=';')

# %%
df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# std        1.570960        0.578840       4.628198      1.734447     72.251528
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %%
df.describe()

plt.figure(figsize=(6, 4))
sns.countplot(x='y', data=df)
plt.title('Distribution of Target Variable')
plt.show()

# %%
numerical_features = df.select_dtypes(include=['int64', 'float64']).columns
for feature in numerical_features:
    plt.figure(figsize=(8, 6))
    sns.histplot(df[feature], kde=True)
    plt.title(f'Distribution of {feature}')
    plt.show()


for feature in numerical_features:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='y', y=feature, data=df)
    plt.title(f'{feature} vs. Target Variable')
    plt.show()

# %%
categorical_features = df.select_dtypes(include=['object']).columns
for feature in categorical_features:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=feature, hue='y', data=df)
    plt.title(f'{feature} vs. Target Variable')
    plt.xticks(rotation=45)
    plt.show()


df_encoded = pd.get_dummies(df, columns=categorical_features, drop_first=True)



df_encoded['interaction_feature'] = df_encoded['age'] * df_encoded['campaign']

# %%
df.dropna(inplace=True)

# %%
import warnings
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split
X=df_encoded.drop('y',axis=1)
y=df_encoded['y']
y = (y == 'yes').astype(int)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

print('X_train:',X_train.shape)
print('y_train:',y_train.shape)
print('X_test:',X_test.shape)
print('y_test:',y_test.shape)
# Out:
# X_train: (28831, 63)
# y_train: (28831,)
# X_test: (12357, 63)
# y_test: (12357,)

# %%
from tensorflow. keras import layers 
from tensorflow. keras.models import Sequential
model = Sequential()
model.add (layers.Dense(32,activation='sigmoid', input_shape=(X_train.shape[1],)))
model.add (layers.Dense(1, activation='linear'))
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_16 (Dense)                │ (None, 32)             │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,081 (8.13 KB)
#  Trainable params: 2,081 (8.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')
model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=60)


optimizer = Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
# Out:
# Epoch 1/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 0.0641 - val_loss: 0.0637
# Epoch 2/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step - loss: 0.0647 - val_loss: 0.0636
# Epoch 3/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 329us/step - loss: 0.0642 - val_loss: 0.0645
# Epoch 4/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step - loss: 0.0649 - val_loss: 0.0639
# Epoch 5/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 338us/step - loss: 0.0645 - val_loss: 0.0631
# Epoch 6/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 343us/step - loss: 0.0629 - val_loss: 0.0631
# Epoch 7/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 0.0642 - val_loss: 0.0632
# Epoch 8/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 349us/step - loss: 0.0639 - val_loss: 0.0631
# Epoch 9/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step - loss: 0.0647 - val_loss: 0.0636
# Epoch 10/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 0.0646 - val_loss: 0.0632
# Epoch 11/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 0.0632 - val_loss: 0.0631
# Epoch 12/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 338us/step - loss: 0.0630 - val_loss: 0.0631
# Epoch 13/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 338us/step - loss: 0.0635 - val_loss: 0.0631
# Epoch 14/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - loss: 0.0639 - val_loss: 0.0630
# Epoch 15/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 0.0644 - val_loss: 0.0630
# Epoch 16/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step - loss: 0.0632 - val_loss: 0.0635
# Epoch 17/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 0.0645 - val_loss: 0.0629
# Epoch 18/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 358us/step - loss: 0.0635 - val_loss: 0.0629
# Epoch 19/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step - loss: 0.0636 - val_loss: 0.0633
# Epoch 20/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step - loss: 0.0627 - val_loss: 0.0634
# Epoch 21/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 0.0644 - val_loss: 0.0629
# Epoch 22/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 344us/step - loss: 0.0643 - val_loss: 0.0629
# Epoch 23/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 355us/step - loss: 0.0643 - val_loss: 0.0629
# Epoch 24/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 0.0631 - val_loss: 0.0628
# Epoch 25/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 0.0639 - val_loss: 0.0630
# Epoch 26/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 351us/step - loss: 0.0633 - val_loss: 0.0628
# Epoch 27/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step - loss: 0.0618 - val_loss: 0.0628
# Epoch 28/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 340us/step - loss: 0.0633 - val_loss: 0.0628
# Epoch 29/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 348us/step - loss: 0.0644 - val_loss: 0.0627
# Epoch 30/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 346us/step - loss: 0.0648 - val_loss: 0.0627
# Epoch 31/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - loss: 0.0640 - val_loss: 0.0632
# Epoch 32/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 0.0626 - val_loss: 0.0628
# Epoch 33/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step - loss: 0.0646 - val_loss: 0.0636
# Epoch 34/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 325us/step - loss: 0.0636 - val_loss: 0.0628
# Epoch 35/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 340us/step - loss: 0.0624 - val_loss: 0.0628
# Epoch 36/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - loss: 0.0645 - val_loss: 0.0627
# Epoch 37/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 349us/step - loss: 0.0632 - val_loss: 0.0627
# Epoch 38/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 340us/step - loss: 0.0642 - val_loss: 0.0632
# Epoch 39/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 0.0636 - val_loss: 0.0632
# Epoch 40/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step - loss: 0.0623 - val_loss: 0.0628
# Epoch 41/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 0.0636 - val_loss: 0.0628
# Epoch 42/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 342us/step - loss: 0.0628 - val_loss: 0.0631
# Epoch 43/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - loss: 0.0638 - val_loss: 0.0626
# Epoch 44/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - loss: 0.0632 - val_loss: 0.0631
# Epoch 45/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 343us/step - loss: 0.0626 - val_loss: 0.0632
# Epoch 46/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 351us/step - loss: 0.0634 - val_loss: 0.0626
# Epoch 47/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 340us/step - loss: 0.0653 - val_loss: 0.0627
# Epoch 48/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 354us/step - loss: 0.0637 - val_loss: 0.0626
# Epoch 49/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 0.0639 - val_loss: 0.0626
# Epoch 50/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - loss: 0.0631 - val_loss: 0.0628
# Epoch 51/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 325us/step - loss: 0.0638 - val_loss: 0.0626
# Epoch 52/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step - loss: 0.0649 - val_loss: 0.0626
# Epoch 53/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 325us/step - loss: 0.0629 - val_loss: 0.0628
# Epoch 54/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - loss: 0.0631 - val_loss: 0.0630
# Epoch 55/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step - loss: 0.0624 - val_loss: 0.0628
# Epoch 56/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 351us/step - loss: 0.0627 - val_loss: 0.0627
# Epoch 57/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 349us/step - loss: 0.0625 - val_loss: 0.0625
# Epoch 58/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step - loss: 0.0618 - val_loss: 0.0626
# Epoch 59/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step - loss: 0.0629 - val_loss: 0.0626
# Epoch 60/60
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 338us/step - loss: 0.0638 - val_loss: 0.0628

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_acc}')
# Out:
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 0s 246us/step - accuracy: 0.9048 - loss: 0.2078
# Test Loss: 0.19947856664657593
# Test Accuracy: 0.9086347818374634

# %%
y_pred = (model.predict(X_test) > 0.5).astype(int)

# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 0s 250us/step
